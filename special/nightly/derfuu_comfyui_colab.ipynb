# %% [markdown]
# <a href="https://colab.research.google.com/github/Guerrero7077/koc7/blob/master/special/nightly/derfuu_comfyui_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Actualiza el sistema e instala aria2
# !apt update -q
# !apt install -y aria2

# Downgrade de NumPy para compatibilidad con PyTorch
# !pip install -q numpy==1.26.4

# Clona ComfyUI
# !git clone https://github.com/comfyanonymous/ComfyUI.git /content/ComfyUI
# %cd /content/ComfyUI
# !pip install -q -r requirements.txt

# Descarga modelos
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/black-forest-labs/FLUX.1-schnell/resolve/main/flux1-schnell.safetensors -d /content/ComfyUI/models/checkpoints -o flux1-schnell.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/XLabs-AI/flux-controlnet-canny/resolve/main/controlnet.safetensors -d /content/ComfyUI/models/xlabs/controlnets -o flux-canny-controlnet-v3.safetensors

# Descarga e instala ComfyUI_flux manualmente
# !wget -q https://github.com/comfyanonymous/ComfyUI_flux/archive/refs/heads/main.zip -O /content/ComfyUI_flux.zip
# !unzip -q /content/ComfyUI_flux.zip -d /content/ComfyUI/custom_nodes/
# !mv /content/ComfyUI/custom_nodes/ComfyUI_flux-main /content/ComfyUI/custom_nodes/ComfyUI_flux
# %cd /content/ComfyUI/custom_nodes/ComfyUI_flux
# !pip install -q -r requirements.txt
# %cd /content/ComfyUI

# Descarga Cloudflare
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O /content/cloudflared-linux-amd64
# !chmod +x /content/cloudflared-linux-amd64

print("Instalación completa. Ahora ejecuta la siguiente celda para iniciar ComfyUI.")
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,383 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,804 kB]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
# Elimina cualquier instalación previa de x-flux-comfyui
# !rm -rf /content/ComfyUI/custom_nodes/x-flux-comfyui

# Clona el repositorio de XLabs-AI
# !git clone https://github.com/XLabs-AI/x-flux-comfyui.git /content/ComfyUI/custom_nodes/x-flux-comfyui
# %cd /content/ComfyUI/custom_nodes/x-flux-comfyui

# Instala dependencias con más detalle
# !pip install -q -r requirements.txt
# !python setup.py install  # Asegura que se instale como módulo si aplica

# Vuelve al directorio principal
# %cd /content/ComfyUI

print("Instalación de XLabs-AI/x-flux-comfyui completada. Ahora ejecuta tu Celda 2.")
# Out:
# Cloning into '/content/ComfyUI/custom_nodes/x-flux-comfyui'...
# remote: Enumerating objects: 669, done.
# remote: Counting objects: 100% (232/232), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 669 (delta 217), reused 168 (delta 167), pack-reused 437 (from 2)
# Receiving objects: 100% (669/669), 1.75 MiB | 4.25 MiB/s, done.
# Resolving deltas: 100% (407/407), done.
# /content/ComfyUI/custom_nodes/x-flux-comfyui
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 2.6 MB/s eta 0:00:00
# ...
# Succesfully installed
# /content/ComfyUI
# Instalación de XLabs-AI/x-flux-comfyui completada. Ahora ejecuta tu Celda 2.

# %%
# Instala ComfyUI Manager en custom_nodes
# %cd /content/ComfyUI/custom_nodes
# !git clone https://github.com/ltdrdata/ComfyUI-Manager.git
# %cd /content/ComfyUI
print("ComfyUI Manager instalado. Reinicia ComfyUI después de esto.")
# Out:
# /content/ComfyUI/custom_nodes
# Cloning into 'ComfyUI-Manager'...
# remote: Enumerating objects: 18805, done.
# remote: Counting objects: 100% (3293/3293), done.
# remote: Compressing objects: 100% (361/361), done.
# remote: Total 18805 (delta 3076), reused 2932 (delta 2932), pack-reused 15512 (from 3)
# Receiving objects: 100% (18805/18805), 27.64 MiB | 11.99 MiB/s, done.
# Resolving deltas: 100% (13911/13911), done.
# /content/ComfyUI
# ComfyUI Manager instalado. Reinicia ComfyUI después de esto.

# %%
# Cambia al directorio de checkpoints y descarga Flux Schnell FP8
# %cd /content/ComfyUI/models/checkpoints
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Kijai/flux-fp8/resolve/main/flux1-schnell-fp8.safetensors -d /content/ComfyUI/models/checkpoints -o flux1-schnell-fp8.safetensors

# Descarga el VAE
# %cd /content/ComfyUI/models/vae
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/black-forest-labs/FLUX.1-schnell/resolve/main/ae.safetensors -d /content/ComfyUI/models/vae -o ae.safetensors

# Descarga los modelos CLIP
# %cd /content/ComfyUI/models/clip
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/comfyanonymous/flux_text_encoders/resolve/main/clip_l.safetensors -d /content/ComfyUI/models/clip -o clip_l.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/comfyanonymous/flux_text_encoders/resolve/main/t5xxl_fp8_e4m3fn.safetensors -d /content/ComfyUI/models/clip -o t5xxl_fp8_e4m3fn.safetensors

# Verifica los archivos descargados
# !ls -lh /content/ComfyUI/models/checkpoints
# !ls -lh /content/ComfyUI/models/vae
# !ls -lh /content/ComfyUI/models/clip
# Out:
# /content/ComfyUI/models/checkpoints
#
# 04/07 20:53:23 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/Kijai/flux-fp8/resolve/main/flux1-schnell-fp8.safetensors
# Exception: [AbstractCommand.cc:351] errorCode=3 URI=https://huggingface.co/Kijai/flux-fp8/resolve/main/flux1-schnell-fp8.safetensors
#   -> [HttpSkipResponseCommand.cc:218] errorCode=3 Resource not found
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 769194|ERR |       0B/s|/content/ComfyUI/models/checkpoints/flux1-schnell-fp8.safetensors
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
# /content/ComfyUI/models/vae
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ...

# %%
# Cambia al directorio de unet
# %cd /content/ComfyUI/models/unet
# Descarga Flux Schnell GGUF (Q4_K_S) con el nombre correcto
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/city96/FLUX.1-schnell-gguf/resolve/main/flux1-schnell-Q4_K_S.gguf -d /content/ComfyUI/models/unet -o flux1-schnell-Q4_K_S.gguf
# Verifica
# !ls -lh /content/ComfyUI/models/unet
# Out:
# /content/ComfyUI/models/unet
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# d0bfc7|OK  |   122MiB/s|/content/ComfyUI/models/unet/flux1-schnell-Q4_K_S.gguf
#
# Status Legend:
# (OK):download completed.
# total 6.4G
# -rw-r--r-- 1 root root 6.4G Apr  7 21:16 flux1-schnell-Q4_K_S.gguf
# -rw-r--r-- 1 root root    0 Apr  7 20:23 put_unet_files_here

# %%
# Cambia al directorio de nodos personalizados
# %cd /content/ComfyUI/custom_nodes
# Clona el repositorio ComfyUI-GGUF
# !git clone https://github.com/city96/ComfyUI-GGUF.git
# Instala dependencias
# %cd ComfyUI-GGUF
# !pip install -q -r requirements.txt
# Out:
# /content/ComfyUI/custom_nodes
# Cloning into 'ComfyUI-GGUF'...
# remote: Enumerating objects: 508, done.
# remote: Counting objects: 100% (274/274), done.
# remote: Compressing objects: 100% (124/124), done.
# remote: Total 508 (delta 231), reused 168 (delta 150), pack-reused 234 (from 2)
# Receiving objects: 100% (508/508), 144.03 KiB | 733.00 KiB/s, done.
# Resolving deltas: 100% (317/317), done.
# /content/ComfyUI/custom_nodes/ComfyUI-GGUF
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 3.0 MB/s eta 0:00:00

# %%
# %cd /content/ComfyUI
# !pkill -f "python main.py"  # Mata cualquier instancia previa de ComfyUI
# !nohup /content/cloudflared-linux-amd64 --url http://localhost:8188 &
# !sleep 5
# !cat /content/ComfyUI/nohup.out
# !python main.py --dont-print-server --log-level DEBUG
# Out:
# /content/ComfyUI
# nohup: appending output to 'nohup.out'
# 2025-04-07T20:27:17Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2025-04-07T20:27:17Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2025-04-07T20:27:20Z INF +--------------------------------------------------------------------------------------------+
# 2025-04-07T20:27:20Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# ...

# %%
# %cd /content/ComfyUI/custom_nodes/ComfyUI-GGUF
# !pip install -q -r requirements.txt
# Out:
# /content/ComfyUI/custom_nodes/ComfyUI-GGUF

# %%
# %cd /content/ComfyUI
# !python -c "import importlib; module = importlib.import_module('custom_nodes.ComfyUI-GGUF'); print(module.nodes.NODE_CLASS_MAPPINGS)"
# Out:
# /content/ComfyUI
# {'UnetLoaderGGUF': <class 'custom_nodes.ComfyUI-GGUF.nodes.UnetLoaderGGUF'>, 'CLIPLoaderGGUF': <class 'custom_nodes.ComfyUI-GGUF.nodes.CLIPLoaderGGUF'>, 'DualCLIPLoaderGGUF': <class 'custom_nodes.ComfyUI-GGUF.nodes.DualCLIPLoaderGGUF'>, 'TripleCLIPLoaderGGUF': <class 'custom_nodes.ComfyUI-GGUF.nodes.TripleCLIPLoaderGGUF'>, 'UnetLoaderGGUFAdvanced': <class 'custom_nodes.ComfyUI-GGUF.nodes.UnetLoaderGGUFAdvanced'>}

# %%
# !cat /content/ComfyUI/custom_nodes/ComfyUI-GGUF/nodes.py
# Out:
# # (c) City96 || Apache-2.0 (apache.org/licenses/LICENSE-2.0)
# import torch
# import logging
# import collections
#
# import comfy.sd
# import comfy.utils
# import comfy.model_patcher
# import comfy.model_management
# import folder_paths
#
# from .ops import GGMLOps, move_patch_to_device
# from .loader import gguf_sd_loader, gguf_clip_loader
# from .dequant import is_quantized, is_torch_compatible
#
# def update_folder_names_and_paths(key, targets=[]):
#     # check for existing key
#     base = folder_paths.folder_names_and_paths.get(key, ([], {}))
#     base = base[0] if isinstance(base[0], (list, set, tuple)) else []
#     # find base key & add w/ fallback, sanity check + warning
#     target = next((x for x in targets if x in folder_paths.folder_names_and_paths), targets[0])
#     orig, _ = folder_paths.folder_names_and_paths.get(target, ([], {}))
#     folder_paths.folder_names_and_paths[key] = (orig or base, {".gguf"})
#     if base and base != orig:
# ...

# %%
# %cd /content/ComfyUI
# !nohup /content/cloudflared-linux-amd64 --url http://localhost:8188 &
# !sleep 5
# !cat /content/ComfyUI/nohup.out
# !python main.py --dont-print-server
# Out:
# /content/ComfyUI
# nohup: appending output to 'nohup.out'
# 2025-04-07T20:27:17Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2025-04-07T20:27:17Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2025-04-07T20:27:20Z INF +--------------------------------------------------------------------------------------------+
# 2025-04-07T20:27:20Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# ...
